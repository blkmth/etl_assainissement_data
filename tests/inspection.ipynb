# %% [markdown]
# # Inspection de notre dataframe n°1 pour definir les fonctions de (transforme) de notre ETL

# %%
import pandas  as pd

# %%
### Importation du dataframe finance

# %%
df = pd.read_csv("/home/charles-nguessan/faux/données/finance_dataset.csv")

# %%
### inspection du dataframe finance_dataset.csv

# %%
df
# Out:
#               id        nom      prenom                      email  \
# 0              1       Barr       Heidi   qhenderson@example.org!!
# 1              2   Saunders     Cynthia      darlene87@example.net
# 2              3  Blanchard  Benjamin??      yhamilton@example.net
# 3              4      Ochoa     Melissa   greengregory@example.org
# 4              5    Jimenez        Ryan      tranderek@example.net
# ...          ...        ...         ...                        ...
# 1099995  1099996     Fisher      Jerome     shanebrown@example.org
# 1099996  1099997    Ramirez       D?rek       xnichols@example.com
# 1099997  1099998    Bennett      Ian@@@                        NaN
# 1099998  1099999    Mccoy        Albert  vanessastokes@example.net
# 1099999  1100000   Stafford        Toni         sadams@example.com
#
#                              pays  revenu_annuel  depenses_annuelles  \
# 0                           China        84596.0             28238.0
# ...

# %%
df.tail(20)
# Out:
#               id        nom      prenom                      email  \
# 1099980  1099981     Brewer      Travi!    riddlekevin@example.com
# 1099981  1099982        NaN       Katie  jeremyfarrell@exa~ple.org
# 1099982  1099983     Willis       Diana   jasmine59@example.net@@@
# 1099983  1099984      Davis      Lauren       ashley78@exam?le.com
# 1099984  1099985    White    Jacqueline      cameron82@example.com
# 1099985  1099986     Graham     Jeffrey        dnewman@example.com
# 1099986  1099987      Roach      Andrea    reidmichael@example.com
# 1099987  1099988     Harris        Alan        fmonroe@example.com
# 1099988  1099989   Powell??       Tonya  martinezsarah@example.com
# 1099989  1099990       Long       Faith     jesselewis@example.net
# 1099990  1099991      Hicks   Francisco         esmith@example.com
# 1099991  1099992      Jones    Glenda       victoria48@example.net
# 1099992  1099993       Reed     Gil!ert       ashley46@example.net
# ...

# %%
df.isnull().count()
# Out:
# id                       1100000
# nom                      1100000
# prenom                   1100000
# email                    1100000
# pays                     1100000
# revenu_annuel            1100000
# depenses_annuelles       1100000
# solde_compte             1100000
# numero_carte             1100000
# transaction_mensuelle    1100000
# dtype: int64

# %%
df.duplicated().count()
# Out:
# 1100000

# %% [markdown]
# # Inspection du second dataframe pour definir les fonctions transformes de  notre ETL

# %%
### Importation du fichers pour la vente des  voitures (car_prices.csv)

# %%
df_2 = pd.read_csv("/home/charles-nguessan/Documents/archive/car_prices.csv")

# %%
### inspection du dataframe car_prices.csv

# %%
df_2
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df_2.tail(50)
# Out:
#         year           make            model                    trim  \
# 558787  2015         Nissan           Altima                   2.5 S
# 558788  2014      Chevrolet   Silverado 1500                      LT
# 558789  2014     Volkswagen              GTI       Wolfsburg Edition
# 558790  2013         Nissan           Maxima                   3.5 S
# 558791  2012           Ford  Transit Connect               Wagon XLT
# 558792  2011      Chevrolet              HHR                      LT
# 558793  2010       Cadillac     Escalade ESV                  Luxury
# 558794  2007       Chrysler       PT Cruiser                    Base
# 558795  2006       Cadillac              DTS             Performance
# 558796  2013       Chrysler              200                      LX
# 558797  2013        Hyundai          Elantra                     GLS
# 558798  2013  Mercedes-Benz          C-Class                    C250
# 558799  2012           Ford            Focus                      SE
# ...

# %%
df_2.duplicated().count()
# Out:
# 558837
